# %% [markdown]
# ## _PRODIGY INFOTECH Data Science Internship - Task 1_

# %% [markdown]
# #### _TASK: Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population._

# %% [markdown]
# ### Import the necessary libraries and the data set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
population_data = pd.read_csv('WorldBank_Population.csv')

# %% [markdown]
# ### Display the data set

# %%
population_data.shape
# Out:
# (266, 69)

# %%
population_data.head(5)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
population_data.describe
# Out:
# <bound method NDFrame.describe of                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %%
# Drop Unnamed Column
population_data.drop("Unnamed: 68", axis=1)
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %% [markdown]
# ### Extract the relevent columns

# %%
data_2023 = population_data.loc[:, ['Country Name', '2023']]

# %% [markdown]
# ### Remove Rows with Missing Values

# %%
data_2023.dropna()
# Out:
#                     Country Name         2023
# 0                          Aruba     107359.0
# 1    Africa Eastern and Southern  750503764.0
# 2                    Afghanistan   41454761.0
# 3     Africa Western and Central  509398589.0
# 4                         Angola   36749906.0
# ..                           ...          ...
# 261                       Kosovo    1756366.0
# 262                  Yemen, Rep.   39390799.0
# 263                 South Africa   63212384.0
# 264                       Zambia   20723965.0
# 265                     Zimbabwe   16340822.0
#
# [265 rows x 2 columns]

# %%
data_2023.head()
# Out:
#                   Country Name         2023
# 0                        Aruba     107359.0
# 1  Africa Eastern and Southern  750503764.0
# 2                  Afghanistan   41454761.0
# 3   Africa Western and Central  509398589.0
# 4                       Angola   36749906.0

# %% [markdown]
# ### Visualize the data using a Histogram

# %%
# Set up the visual style
sns.set(style="whitegrid")

# Histogram for population distribution in 2022
plt.figure(figsize = (12, 6))
sns.histplot(data = data_2023, x='2023', bins=30, kde=True, color='crimson')
plt.title('Population Distribution in 2023')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Visualize the data using a Bar Chart

# %%
# Sort data by population in descending order and select top 220
top_20_countries = data_2023.sort_values(by='2023', ascending=False).head(20)

# Set up the visual style
sns.set(style="whitegrid")

# Bar chart for top 20 most populous countries in 2023
plt.figure(figsize=(20, 6))
sns.barplot(data = top_20_countries, x='Country Name', y='2023', palette='gist_heat')
plt.title('Top 20 Most Populous Countries in 2023')
plt.xlabel('Country')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.show()
